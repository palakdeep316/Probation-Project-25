# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/palakdeep/Desktop/Probation/Probation-Project-25/Palakdeep_kaur_task_7/Fuel_consumption.csv")
df
# Out:
#      Year   MAKE           MODEL             VEHICLE CLASS  ENGINE SIZE  \
# 0    2000  ACURA           1.6EL                   COMPACT          1.6
# 1    2000  ACURA           1.6EL                   COMPACT          1.6
# 2    2000  ACURA           3.2TL                  MID-SIZE          3.2
# 3    2000  ACURA           3.5RL                  MID-SIZE          3.5
# 4    2000  ACURA         INTEGRA                SUBCOMPACT          1.8
# ..    ...    ...             ...                       ...          ...
# 634  2000  VOLVO   V70 AWD TURBO  STATION WAGON - MID-SIZE          2.4
# 635  2000  VOLVO   V70 GLT TURBO  STATION WAGON - MID-SIZE          2.4
# 636  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 637  2000  VOLVO    V70 T5 TURBO  STATION WAGON - MID-SIZE          2.3
# 638  2000  VOLVO  V70R AWD TURBO  STATION WAGON - MID-SIZE          2.4
#
#      CYLINDERS TRANSMISSION FUEL  FUEL CONSUMPTION  COEMISSIONS
# ...

# %%
df.isnull().sum()
# Out:
# Year                0
# MAKE                0
# MODEL               0
# VEHICLE CLASS       0
# ENGINE SIZE         0
# CYLINDERS           0
# TRANSMISSION        0
# FUEL                0
# FUEL CONSUMPTION    0
# COEMISSIONS         0
# dtype: int64

# %%
df.describe()
# Out:
#          Year  ENGINE SIZE   CYLINDERS  FUEL CONSUMPTION  COEMISSIONS
# count   639.0   639.000000  639.000000        639.000000   639.000000
# mean   2000.0     3.265728    5.805947         14.713615   296.809077
# std       0.0     1.231012    1.625588          3.307044    65.504178
# min    2000.0     1.000000    3.000000          4.900000   104.000000
# 25%    2000.0     2.200000    4.000000         12.500000   253.000000
# 50%    2000.0     3.000000    6.000000         14.400000   288.000000
# 75%    2000.0     4.300000    6.000000         16.600000   343.000000
# max    2000.0     8.000000   12.000000         30.200000   582.000000

# %%
col=["ENGINE SIZE","CYLINDERS","FUEL CONSUMPTION"]
for i in col:
    plt.scatter(df[i],df["COEMISSIONS"],alpha=0.5)
    plt.title(f"Scatter plot of {i} vs COEMISSIONS")
    plt.xlabel(i)
    plt.ylabel("COEMISSIONS")
    plt.show()

# %%
for i in col:
    plt.figure(figsize=(16,2))
    plt.boxplot(df[i], vert=False)
    plt.title(f"Boxplot of {i}")
    plt.xlabel(i)
    plt.show()
plt.figure(figsize=(16,2))
plt.boxplot(df['COEMISSIONS'], vert=False)
plt.title("Boxplot of COEMISSIONS")
plt.xlabel(i)
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, linewidths=0.5)
# Out:
# <Axes: >

# %%
def linear_regression(x,y):
    x=np.array(x).flatten()
    y=np.array(y).flatten()
    x_mean=x.mean()
    y_mean=y.mean()
    m=sum((x-x_mean)*(y-y_mean))/sum((x-x_mean)**2)
    m = sum((x-x_mean)*(y-y_mean))/sum((x-x_mean)**2)
    c = y_mean - (m * x_mean)
    return m,c

# %%
for i in col:
    if ( i == 'CYLINDERS' ):
        continue
    slope, intercept =linear_regression(df[i], df['COEMISSIONS'])
    plt.title(f'LINEAR REGRESSION b/w {i} and COEMISSION')
    plt.xlabel(f'{i}')
    plt.ylabel('COEMISSION')
    plt.plot(df[i], slope*df[i]+intercept, color='black')
    plt.scatter(df[i], df['COEMISSIONS'], color='red', alpha=0.5)
    plt.show()

# %%
def multi(df, features, target):
    X = df[features].values
    y = df[target].values.reshape(-1, 1)
    X_b = np.c_[np.ones((X.shape[0], 1)), X]
    theta = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
    print(f"Intercept (c): {theta[0][0]:.4f}")
    for name, value in zip(features, theta[1:].flatten()):
        print(f"Slope for {name}: {value:.4f}")

    y_pred = X_b.dot(theta)
    plt.figure(figsize=(12, 6))
    plt.title('Multiple Linear Regression')
    plt.xlabel('Actual Values')
    plt.ylabel('Predicted Values')
    plt.scatter(df[target], y_pred, color='black', alpha=0.5)
    plt.show()

    return theta, y_pred

# %%
features = ['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION']
target = ['COEMISSIONS']
multi(df,features, target)
# Out:
# Intercept (c): 16.3820
# Slope for ENGINE SIZE: 4.7098
# Slope for CYLINDERS: -3.7850
# Slope for FUEL CONSUMPTION: 19.5072
# (array([[16.38204853],
#         [ 4.70975459],
#         [-3.78502825],
#         [19.50723356]]),
#  array([[213.60349524],
#         [199.94843175],
#         [275.99219347],
#         [302.76452347],
#         [232.10195636],
#         [216.49616952],
#         [220.39761623],
#         [304.31109289],
#         [309.15449052],
#         [261.3628067 ],
#         [226.2497863 ],
#         [291.66480184],
#         [264.35467486],
#         [275.01787019],
#         [245.75701986],
#         [297.51697191],
#         [285.81263177],
#         [299.46769526],
#         [307.27058869],
#         [302.89816652],
#         [302.89816652],
#         [307.27058869],
#         [291.66480184],
#         [308.24491197],
#         [308.24491197],
#         [302.89816652],
#         [302.89816652],
#         [265.26425341],
#         [265.26425341],
# ...
